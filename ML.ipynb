# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split, ParameterGrid, cross_val_score, RepeatedKFold, RepeatedStratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import  MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import warnings  as ws
ws.filterwarnings("ignore")

# %%
EGSS_dataset= pd.read_csv("Data_for_UCI_named.csv")
EGSS_dataset.info()
EGSS_dataset.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stab    10000 non-null  float64
#  13  stabf   10000 non-null  object
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB
# (10000, 14)

# %%
EGSS_dataset.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %%
EGSS_dataset.tail()
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4      stab     stabf
# 9995 -1.236256  0.601709  0.779642  0.813512  0.608385  0.023892  unstable
# 9996 -1.733414  0.502079  0.567242  0.285880  0.366120 -0.025803    stable
# 9997 -1.975373  0.487838  0.986505  0.149286  0.145984 -0.031810    stable
# 9998 -0.898510  0.365246  0.587558  0.889118  0.818391  0.037789  unstable
# 9999 -0.570329  0.073056  0.505441  0.378761  0.942631  0.045263  unstable

# %%
EGSS_dataset.sample(10)
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 2887  4.860059  1.698050  8.491800  0.958622  4.940212 -1.920476 -1.603164
# 2492  4.068763  9.070222  7.497185  9.670969  3.373593 -0.867732 -1.729065
# 8790  9.614408  5.317400  6.979205  5.409695  5.229216 -1.832939 -1.677263
# 3037  3.383049  7.616788  8.011237  0.810401  2.715116 -0.853039 -0.784022
# 1161  6.281070  6.086208  6.308425  3.074090  5.105842 -1.670995 -1.987155
# 1725  5.155116  4.449728  6.973148  6.080182  4.752119 -1.152313 -1.608821
# 98    4.913955  8.077515  5.161089  6.174081  3.641994 -1.061981 -1.730213
# 7154  3.382167  3.851067  4.726026  6.229076  4.256317 -1.759329 -1.046560
# 2540  6.195988  3.896474  5.861782  4.654307  3.898745 -1.642738 -1.395559
# 4547  5.892075  1.671722  6.683416  0.970326  3.239120 -1.747539 -0.629752
#
#             p4        g1        g2        g3        g4      stab     stabf
# ...

# %%
EGSS_dataset.describe(include="all")
# Out:
#                 tau1          tau2          tau3          tau4            p1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        5.250000      5.250001      5.250004      5.249997      3.750000
# std         2.742548      2.742549      2.742549      2.742556      0.752160
# min         0.500793      0.500141      0.500788      0.500473      1.582590
# 25%         2.874892      2.875140      2.875522      2.874950      3.218300
# 50%         5.250004      5.249981      5.249979      5.249734      3.751025
# 75%         7.624690      7.624893      7.624948      7.624838      4.282420
# max         9.999469      9.999837      9.999450      9.999443      5.864418
#
# ...

# %%
EGSS_dataset.columns
# Out:
# Index(['tau1', 'tau2', 'tau3', 'tau4', 'p1', 'p2', 'p3', 'p4', 'g1', 'g2',
#        'g3', 'g4', 'stab', 'stabf'],
#       dtype='object')

# %%
EGSS_dataset.isnull().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %%
X = EGSS_dataset[['tau1', 'tau2', 'tau3', 'tau4', 'p2', 'p3', 'p4', 'g1', 'g2','g3', 'g4']].values
y = EGSS_dataset[['stabf']].values.flatten()

# %% [markdown]
# # DATA VISUALIZATION

# %%
import matplotlib as plt

# %matplotlib inline

EGSS_dataset.describe()
# Out:
#                tau1          tau2          tau3          tau4            p1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      3.750000
# std        2.742548      2.742549      2.742549      2.742556      0.752160
# min        0.500793      0.500141      0.500788      0.500473      1.582590
# 25%        2.874892      2.875140      2.875522      2.874950      3.218300
# 50%        5.250004      5.249981      5.249979      5.249734      3.751025
# 75%        7.624690      7.624893      7.624948      7.624838      4.282420
# max        9.999469      9.999837      9.999450      9.999443      5.864418
#
#                  p2            p3            p4            g1            g2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -1.250000     -1.250000     -1.250000      0.525000      0.525000
# ...

# %% [markdown]
# # DATA MODELING

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
